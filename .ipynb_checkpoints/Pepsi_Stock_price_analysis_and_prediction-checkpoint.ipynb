# %% [markdown]
# ## PEPSI STOCK PRICE ANALYSIS AND PREDICTION

# %% [markdown]
# #### Importation of important libraries

# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
from scipy.stats import norm


# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Downloading the dataset from yahoo finance

# %%
from pandas_datareader import data as pdr
import yfinance as yf

yf.pdr_override()

df = pdr.get_data_yahoo("PEP", start="2012-01-01", end="2022-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.to_csv('Pepsi stock price data')

# %% [markdown]
# #### First observations of the dataset

# %%
df.head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_805be_row0_col0, #T_805be_row0_col1, #T_805be_row0_col2, #T_805be_row1_col3, #T_805be_row1_col4, #T_805be_row6_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_805be_row0_col3, #T_805be_row0_col4 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_805be_row0_col5 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_805be_row1_col0 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_805be_row1_col1 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_805be_row1_col2, #T_805be_row2_col2 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_805be_row1_col5 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_805be_row2_col0 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_805be_row2_col1 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_805be_row2_col3, #T_805be_row2_col4 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_805be_row2_col5, #T_805be_row6_col2, #T_805be_row8_col0, #T_805be_row8_col1, #T_805be_row8_col3, #T_805be_row8_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_805be_row3_col0 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_805be_row3_col1 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_805be_row3_col2 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_805be_row3_col3, #T_805be_row3_col4 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_805be_row3_col5 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_805be_row4_col0 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_805be_row4_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_805be_row4_col2 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# #T_805be_row4_col3, #T_805be_row4_col4 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_805be_row4_col5 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_805be_row5_col0 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_805be_row5_col1, #T_805be_row5_col3, #T_805be_row5_col4 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_805be_row5_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_805be_row5_col5 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_805be_row6_col0 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_805be_row6_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_805be_row6_col3, #T_805be_row6_col4 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_805be_row7_col0 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_805be_row7_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_805be_row7_col2 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_805be_row7_col3, #T_805be_row7_col4 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_805be_row7_col5, #T_805be_row9_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_805be_row8_col2 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_805be_row8_col5 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_805be_row9_col0 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_805be_row9_col2 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_805be_row9_col3, #T_805be_row9_col4 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_805be_row9_col5 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_805be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_805be_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_805be_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_805be_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_805be_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_805be_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_805be_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_805be_level0_row0" class="row_heading level0 row0" >2012-01-03 00:00:00</th>
#       <td id="T_805be_row0_col0" class="data row0 col0" >66.860001</td>
#       <td id="T_805be_row0_col1" class="data row0 col1" >67.190002</td>
#       <td id="T_805be_row0_col2" class="data row0 col2" >66.360001</td>
#       <td id="T_805be_row0_col3" class="data row0 col3" >66.400002</td>
#       <td id="T_805be_row0_col4" class="data row0 col4" >48.919064</td>
#       <td id="T_805be_row0_col5" class="data row0 col5" >5348800</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row1" class="row_heading level0 row1" >2012-01-04 00:00:00</th>
#       <td id="T_805be_row1_col0" class="data row1 col0" >66.410004</td>
#       <td id="T_805be_row1_col1" class="data row1 col1" >66.839996</td>
#       <td id="T_805be_row1_col2" class="data row1 col2" >66.120003</td>
#       <td id="T_805be_row1_col3" class="data row1 col3" >66.739998</td>
#       <td id="T_805be_row1_col4" class="data row1 col4" >49.169552</td>
#       <td id="T_805be_row1_col5" class="data row1 col5" >6042400</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row2" class="row_heading level0 row2" >2012-01-05 00:00:00</th>
#       <td id="T_805be_row2_col0" class="data row2 col0" >66.580002</td>
#       <td id="T_805be_row2_col1" class="data row2 col1" >66.669998</td>
#       <td id="T_805be_row2_col2" class="data row2 col2" >66.120003</td>
#       <td id="T_805be_row2_col3" class="data row2 col3" >66.220001</td>
#       <td id="T_805be_row2_col4" class="data row2 col4" >48.786453</td>
#       <td id="T_805be_row2_col5" class="data row2 col5" >4909100</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row3" class="row_heading level0 row3" >2012-01-06 00:00:00</th>
#       <td id="T_805be_row3_col0" class="data row3 col0" >66.269997</td>
#       <td id="T_805be_row3_col1" class="data row3 col1" >66.269997</td>
#       <td id="T_805be_row3_col2" class="data row3 col2" >65.290001</td>
#       <td id="T_805be_row3_col3" class="data row3 col3" >65.389999</td>
#       <td id="T_805be_row3_col4" class="data row3 col4" >48.174973</td>
#       <td id="T_805be_row3_col5" class="data row3 col5" >6533000</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row4" class="row_heading level0 row4" >2012-01-09 00:00:00</th>
#       <td id="T_805be_row4_col0" class="data row4 col0" >65.260002</td>
#       <td id="T_805be_row4_col1" class="data row4 col1" >65.830002</td>
#       <td id="T_805be_row4_col2" class="data row4 col2" >65.010002</td>
#       <td id="T_805be_row4_col3" class="data row4 col3" >65.730003</td>
#       <td id="T_805be_row4_col4" class="data row4 col4" >48.425457</td>
#       <td id="T_805be_row4_col5" class="data row4 col5" >5859600</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row5" class="row_heading level0 row5" >2012-01-10 00:00:00</th>
#       <td id="T_805be_row5_col0" class="data row5 col0" >65.980003</td>
#       <td id="T_805be_row5_col1" class="data row5 col1" >66.050003</td>
#       <td id="T_805be_row5_col2" class="data row5 col2" >65.470001</td>
#       <td id="T_805be_row5_col3" class="data row5 col3" >65.660004</td>
#       <td id="T_805be_row5_col4" class="data row5 col4" >48.373886</td>
#       <td id="T_805be_row5_col5" class="data row5 col5" >4996000</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row6" class="row_heading level0 row6" >2012-01-11 00:00:00</th>
#       <td id="T_805be_row6_col0" class="data row6 col0" >65.000000</td>
#       <td id="T_805be_row6_col1" class="data row6 col1" >65.169998</td>
#       <td id="T_805be_row6_col2" class="data row6 col2" >64.129997</td>
#       <td id="T_805be_row6_col3" class="data row6 col3" >65.010002</td>
#       <td id="T_805be_row6_col4" class="data row6 col4" >47.895012</td>
#       <td id="T_805be_row6_col5" class="data row6 col5" >10470200</td>
#     </tr>
#     <tr>
#       <th id="T_805be_level0_row7" class="row_heading level0 row7" >2012-01-12 00:00:00</th>
#       <td id

# %%
df.tail(10).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_a894b_row0_col0, #T_a894b_row0_col1, #T_a894b_row0_col2, #T_a894b_row1_col1, #T_a894b_row1_col3, #T_a894b_row1_col4, #T_a894b_row3_col2, #T_a894b_row6_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a894b_row0_col3, #T_a894b_row0_col4 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_a894b_row0_col5 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_a894b_row1_col0, #T_a894b_row2_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_a894b_row1_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a894b_row1_col5, #T_a894b_row6_col2, #T_a894b_row6_col3, #T_a894b_row6_col4, #T_a894b_row8_col0, #T_a894b_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a894b_row2_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_a894b_row2_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_a894b_row2_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_a894b_row2_col3, #T_a894b_row2_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_a894b_row3_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_a894b_row3_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a894b_row3_col3, #T_a894b_row3_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_a894b_row3_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_a894b_row4_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_a894b_row4_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_a894b_row4_col2 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_a894b_row4_col3, #T_a894b_row4_col4, #T_a894b_row5_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_a894b_row4_col5 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_a894b_row5_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_a894b_row5_col1 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_a894b_row5_col3, #T_a894b_row5_col4 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_a894b_row5_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_a894b_row6_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_a894b_row6_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a894b_row7_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_a894b_row7_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_a894b_row7_col2 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_a894b_row7_col3, #T_a894b_row7_col4 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_a894b_row7_col5 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_a894b_row8_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_a894b_row8_col3, #T_a894b_row8_col4 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_a894b_row8_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_a894b_row9_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_a894b_row9_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_a894b_row9_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_a894b_row9_col3, #T_a894b_row9_col4 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_a894b_row9_col5 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# </style>
# <table id="T_a894b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a894b_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_a894b_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_a894b_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_a894b_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_a894b_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_a894b_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a894b_level0_row0" class="row_heading level0 row0" >2022-06-29 00:00:00</th>
#       <td id="T_a894b_row0_col0" class="data row0 col0" >166.059998</td>
#       <td id="T_a894b_row0_col1" class="data row0 col1" >167.559998</td>
#       <td id="T_a894b_row0_col2" class="data row0 col2" >165.350006</td>
#       <td id="T_a894b_row0_col3" class="data row0 col3" >166.729996</td>
#       <td id="T_a894b_row0_col4" class="data row0 col4" >166.729996</td>
#       <td id="T_a894b_row0_col5" class="data row0 col5" >3653600</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row1" class="row_heading level0 row1" >2022-06-30 00:00:00</th>
#       <td id="T_a894b_row1_col0" class="data row1 col0" >167.130005</td>
#       <td id="T_a894b_row1_col1" class="data row1 col1" >167.580002</td>
#       <td id="T_a894b_row1_col2" class="data row1 col2" >165.630005</td>
#       <td id="T_a894b_row1_col3" class="data row1 col3" >166.660004</td>
#       <td id="T_a894b_row1_col4" class="data row1 col4" >166.660004</td>
#       <td id="T_a894b_row1_col5" class="data row1 col5" >6295100</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row2" class="row_heading level0 row2" >2022-07-01 00:00:00</th>
#       <td id="T_a894b_row2_col0" class="data row2 col0" >166.740005</td>
#       <td id="T_a894b_row2_col1" class="data row2 col1" >169.520004</td>
#       <td id="T_a894b_row2_col2" class="data row2 col2" >165.759995</td>
#       <td id="T_a894b_row2_col3" class="data row2 col3" >169.389999</td>
#       <td id="T_a894b_row2_col4" class="data row2 col4" >169.389999</td>
#       <td id="T_a894b_row2_col5" class="data row2 col5" >3918400</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row3" class="row_heading level0 row3" >2022-07-05 00:00:00</th>
#       <td id="T_a894b_row3_col0" class="data row3 col0" >168.630005</td>
#       <td id="T_a894b_row3_col1" class="data row3 col1" >169.389999</td>
#       <td id="T_a894b_row3_col2" class="data row3 col2" >165.330002</td>
#       <td id="T_a894b_row3_col3" class="data row3 col3" >169.009995</td>
#       <td id="T_a894b_row3_col4" class="data row3 col4" >169.009995</td>
#       <td id="T_a894b_row3_col5" class="data row3 col5" >4971600</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row4" class="row_heading level0 row4" >2022-07-06 00:00:00</th>
#       <td id="T_a894b_row4_col0" class="data row4 col0" >170.000000</td>
#       <td id="T_a894b_row4_col1" class="data row4 col1" >171.949997</td>
#       <td id="T_a894b_row4_col2" class="data row4 col2" >169.479996</td>
#       <td id="T_a894b_row4_col3" class="data row4 col3" >170.699997</td>
#       <td id="T_a894b_row4_col4" class="data row4 col4" >170.699997</td>
#       <td id="T_a894b_row4_col5" class="data row4 col5" >4209100</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row5" class="row_heading level0 row5" >2022-07-07 00:00:00</th>
#       <td id="T_a894b_row5_col0" class="data row5 col0" >169.520004</td>
#       <td id="T_a894b_row5_col1" class="data row5 col1" >171.039993</td>
#       <td id="T_a894b_row5_col2" class="data row5 col2" >169.380005</td>
#       <td id="T_a894b_row5_col3" class="data row5 col3" >170.360001</td>
#       <td id="T_a894b_row5_col4" class="data row5 col4" >170.360001</td>
#       <td id="T_a894b_row5_col5" class="data row5 col5" >5150200</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row6" class="row_heading level0 row6" >2022-07-08 00:00:00</th>
#       <td id="T_a894b_row6_col0" class="data row6 col0" >170.570007</td>
#       <td id="T_a894b_row6_col1" class="data row6 col1" >172.699997</td>
#       <td id="T_a894b_row6_col2" class="data row6 col2" >170.550003</td>
#       <td id="T_a894b_row6_col3" class="data row6 col3" >171.880005</td>
#       <td id="T_a894b_row6_col4" class="data row6 col4" >171.880005</td>
#       <td id="T_a894b_row6_col5" class="data row6 col5" >3482900</td>
#     </tr>
#     <tr>
#       <th id="T_a894b_level0_row7" class="row_heading level0 row7" >2022-07-11 00:00:00</th>
#       <td id="T_a894b_row7_c

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2649 entries, 2012-01-03 to 2022-07-13
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2649 non-null   float64
#  1   High       2649 non-null   float64
#  2   Low        2649 non-null   float64
#  3   Close      2649 non-null   float64
#  4   Adj Close  2649 non-null   float64
#  5   Volume     2649 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 144.9 KB

# %% [markdown]
# This dataset contains Pepsi stock price values from "3rd Jan, 2012" to "13th of July, 2022". It contains 10years of Pepsi stock data price data with 2649 entries and no missing data.

# %% [markdown]
# #### Summary of statistics performed on the dataset

# %%
df.describe().style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_ae7b1_row0_col0, #T_ae7b1_row0_col1, #T_ae7b1_row0_col2, #T_ae7b1_row0_col3, #T_ae7b1_row0_col4, #T_ae7b1_row7_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ae7b1_row0_col5, #T_ae7b1_row2_col0, #T_ae7b1_row2_col1, #T_ae7b1_row2_col2, #T_ae7b1_row2_col3, #T_ae7b1_row2_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ae7b1_row1_col0, #T_ae7b1_row1_col1, #T_ae7b1_row1_col2, #T_ae7b1_row1_col3, #T_ae7b1_row3_col5, #T_ae7b1_row6_col4 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_ae7b1_row1_col4, #T_ae7b1_row4_col0, #T_ae7b1_row4_col1, #T_ae7b1_row4_col2, #T_ae7b1_row4_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_ae7b1_row1_col5 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_ae7b1_row2_col5 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_ae7b1_row3_col0, #T_ae7b1_row3_col1, #T_ae7b1_row3_col2, #T_ae7b1_row3_col3, #T_ae7b1_row4_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_ae7b1_row3_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_ae7b1_row4_col5 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_ae7b1_row5_col0, #T_ae7b1_row5_col1, #T_ae7b1_row5_col2, #T_ae7b1_row5_col3 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_ae7b1_row5_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_ae7b1_row5_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_ae7b1_row6_col0, #T_ae7b1_row6_col1, #T_ae7b1_row6_col2, #T_ae7b1_row6_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_ae7b1_row6_col5 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_ae7b1_row7_col0, #T_ae7b1_row7_col1, #T_ae7b1_row7_col2, #T_ae7b1_row7_col3, #T_ae7b1_row7_col4 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# </style>
# <table id="T_ae7b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae7b1_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_ae7b1_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_ae7b1_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_ae7b1_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_ae7b1_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_ae7b1_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae7b1_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ae7b1_row0_col0" class="data row0 col0" >2649.000000</td>
#       <td id="T_ae7b1_row0_col1" class="data row0 col1" >2649.000000</td>
#       <td id="T_ae7b1_row0_col2" class="data row0 col2" >2649.000000</td>
#       <td id="T_ae7b1_row0_col3" class="data row0 col3" >2649.000000</td>
#       <td id="T_ae7b1_row0_col4" class="data row0 col4" >2649.000000</td>
#       <td id="T_ae7b1_row0_col5" class="data row0 col5" >2649.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ae7b1_row1_col0" class="data row1 col0" >110.653401</td>
#       <td id="T_ae7b1_row1_col1" class="data row1 col1" >111.419309</td>
#       <td id="T_ae7b1_row1_col2" class="data row1 col2" >109.887056</td>
#       <td id="T_ae7b1_row1_col3" class="data row1 col3" >110.684662</td>
#       <td id="T_ae7b1_row1_col4" class="data row1 col4" >97.423104</td>
#       <td id="T_ae7b1_row1_col5" class="data row1 col5" >4854934.050585</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ae7b1_row2_col0" class="data row2 col0" >27.751231</td>
#       <td id="T_ae7b1_row2_col1" class="data row2 col1" >28.021462</td>
#       <td id="T_ae7b1_row2_col2" class="data row2 col2" >27.438357</td>
#       <td id="T_ae7b1_row2_col3" class="data row2 col3" >27.740919</td>
#       <td id="T_ae7b1_row2_col4" class="data row2 col4" >32.746053</td>
#       <td id="T_ae7b1_row2_col5" class="data row2 col5" >2035557.090022</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_ae7b1_row3_col0" class="data row3 col0" >62.330002</td>
#       <td id="T_ae7b1_row3_col1" class="data row3 col1" >62.680000</td>
#       <td id="T_ae7b1_row3_col2" class="data row3 col2" >62.150002</td>
#       <td id="T_ae7b1_row3_col3" class="data row3 col3" >62.279999</td>
#       <td id="T_ae7b1_row3_col4" class="data row3 col4" >46.178425</td>
#       <td id="T_ae7b1_row3_col5" class="data row3 col5" >883300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_ae7b1_row4_col0" class="data row4 col0" >91.480003</td>
#       <td id="T_ae7b1_row4_col1" class="data row4 col1" >91.889999</td>
#       <td id="T_ae7b1_row4_col2" class="data row4 col2" >90.760002</td>
#       <td id="T_ae7b1_row4_col3" class="data row4 col3" >91.419998</td>
#       <td id="T_ae7b1_row4_col4" class="data row4 col4" >72.848343</td>
#       <td id="T_ae7b1_row4_col5" class="data row4 col5" >3601600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_ae7b1_row5_col0" class="data row5 col0" >108.040001</td>
#       <td id="T_ae7b1_row5_col1" class="data row5 col1" >108.750000</td>
#       <td id="T_ae7b1_row5_col2" class="data row5 col2" >107.330002</td>
#       <td id="T_ae7b1_row5_col3" class="data row5 col3" >108.050003</td>
#       <td id="T_ae7b1_row5_col4" class="data row5 col4" >92.114204</td>
#       <td id="T_ae7b1_row5_col5" class="data row5 col5" >4471200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_ae7b1_row6_col0" class="data row6 col0" >132.839996</td>
#       <td id="T_ae7b1_row6_col1" class="data row6 col1" >133.839996</td>
#       <td id="T_ae7b1_row6_col2" class="data row6 col2" >131.589996</td>
#       <td id="T_ae7b1_row6_col3" class="data row6 col3" >132.820007</td>
#       <td id="T_ae7b1_row6_col4" class="data row6 col4" >124.053856</td>
#       <td id="T_ae7b1_row6_col5" class="data row6 col5" >5579300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae7b1_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_ae7b1_row7_col0" class="data row7 col0" >177.410004</td>
#       <td id="T_ae7b1_row7_col1" class="data row7 col1" >177.619995</td>
#       <td id="T_ae7b1_row7_col2" class="data row7 col2" >174.649994</td>
#       <td id="T_ae7b1_row7_col3" class="data row7 col3" >177.500000</td>
#       <td id="T_ae7b1_row7_col4" class="data row7 col4" >176.273941</td>
#       <td id="T_ae7b1_row7_col5" class="data row7 col5" >27559700.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[df['High'] == df['High'].max()]
# Out:
#                   Open        High         Low  Close   Adj Close   Volume
# Date
# 2022-04-28  174.529999  177.619995  173.820007  177.5  176.273941  5235800

# %% [markdown]
# The highest value of Pepsi stocks between Jan 2012 and July 2022 was on the 28th April, 2022 with an opening price of 174.5 and a closing price of 177.5

# %%
df[df['Low'] == df['Low'].min()]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2012-03-07  62.330002  62.740002  62.150002  62.619999   46.51252  7509000

# %% [markdown]
# The lowest value of pepsi stocks between Jan 2012 and July 2022 was on 7th March, 2012 with an opening price of 62.3 and a closing price of 62.6

# %% [markdown]
# ### Data Visualization

# %%
fig = plt.figure(figsize=(20,10))
sns.set_style('darkgrid')

cm = ['Green','red']

df[['High', 'Low']].iplot(kind='line', title="High vs Low values of Pepsi stocks",
                          color=cm, xaxis_title='Date')
                                          
df[['Open', 'Close']].iplot(kind='line', title="Opening vs Closing values of pepsi stocks", 
                            colors=cm, xaxis_title='Date')

# %%
df['MA100'] = df['Close'].rolling(100).mean()

# %%
df[['Close', 'MA100']].iplot(kind='line', title= "Close price vs 100days moving average", xaxis_title='Date')

# %% [markdown]
# ##### CREATING THE DAILY RETURNS COLUMN

# %%
df['Daily returns'] = df['Adj Close'].pct_change(1).fillna(0)

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2012-01-03  66.860001  67.190002  66.360001  66.400002  48.919064  5348800
# 2012-01-04  66.410004  66.839996  66.120003  66.739998  49.169552  6042400
# 2012-01-05  66.580002  66.669998  66.120003  66.220001  48.786453  4909100
# 2012-01-06  66.269997  66.269997  65.290001  65.389999  48.174973  6533000
# 2012-01-09  65.260002  65.830002  65.010002  65.730003  48.425457  5859600
#
#             MA100  Daily returns
# Date
# 2012-01-03    NaN       0.000000
# 2012-01-04    NaN       0.005120
# 2012-01-05    NaN      -0.007791
# 2012-01-06    NaN      -0.012534
# 2012-01-09    NaN       0.005199

# %% [markdown]
# #### ANALYSIS ON THE DAILY RETURNS
# ##### probability distrubution of the returns

# %%
fig = plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.hist(df['Daily returns'],bins=10,label="Daily close price")
plt.legend()

# %%
fig = plt.figure(figsize=(10,5))
plt.boxplot(x=df['Daily returns'])
plt.show()

# %%
df['Daily returns'].describe()
# Out:
# count    2649.000000
# mean        0.000532
# std         0.011118
# min        -0.114283
# 25%        -0.004494
# 50%         0.000517
# 75%         0.005781
# max         0.129366
# Name: Daily returns, dtype: float64

# %% [markdown]
# ##### best day of stock

# %%
df[df['Daily returns'] == df['Daily returns'].max()]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-17  116.699997  127.860001  116.389999  127.720001  119.768379
#
#               Volume     MA100  Daily returns
# Date
# 2020-03-17  14242300  137.3421       0.129366

# %% [markdown]
# The highest daily return was on 17th march, 2020 with a return of 0.129

# %% [markdown]
# ##### worst day of stock

# %%
df[df['Daily returns'] == df['Daily returns'].min()]
# Out:
#                   Open        High         Low   Close  Adj Close    Volume  \
# Date
# 2020-03-20  118.239998  118.449997  101.419998  103.93  97.459503  13093200
#
#                MA100  Daily returns
# Date
# 2020-03-20  136.6442      -0.114283

# %% [markdown]
# the lowest daily return was on 20th March, 2020 with a daily return of -0.11

# %% [markdown]
# #### Plotting daily returns over time

# %%
fig = plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
df['Daily returns'].plot()
plt.xlabel("Date", fontsize=15)
plt.ylabel("Percent", fontsize=15)
plt.title("Pepsi Stock Daily Returns", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Pepsi Stock Daily Returns')

# %% [markdown]
# #### Moving avg vs close price

# %%
fig = plt.figure(figsize=(10,5))
df['Close'].rolling(window=30).mean().plot(label='30 Day Avg')
df['Close'].plot(label='CLOSE price')
plt.title("Comparison of the moving average & Close price", fontsize=17)
plt.legend(fontsize=10)

# %% [markdown]
# #### Are the Daily returns normally distributed

# %%
fig = plt.figure(figsize=(10,7))
t = np.linspace(0.01,0.99,1000)
q1 = np.quantile(df['Daily returns'],t)
q2 = norm.ppf(t,loc=np.mean(df['Daily returns']),scale=np.std(df['Daily returns']))
plt.plot(q1,q2)
plt.plot([min(q1),max(q1)],[min(q2),max(q2)])
plt.xlim((min(q1),max(q1)))
plt.ylim((min(q2),max(q2)))
plt.xlabel("Daily returns", fontsize=17)
plt.ylabel("Normal distribution", fontsize=17)
plt.show()

# %% [markdown]
# From the graph above, the straight line is the normal distribution but the daily returns is the blue line with isn't straight therefore indicating that the daily returns isn't distributed normally

# %% [markdown]
# ### Training the dataset

# %%
data=df.sort_index(ascending=True,axis=0)

# %%
# 1. Filter out the closing market price data
close_data = df.filter(['Close'])
 
# 2. Convert the data into array for easy evaluation
dataset = close_data.values
 
# 3. Scale/Normalize the data to make all values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
 
# 4. Creating training data size : 70% of the data
training_data_len = math.ceil(len(dataset) * 0.7)
train_data = scaled_data[0:training_data_len  , : ]
 
# 5. Separating the data into x and y data
x_train_data=[]
y_train_data =[]
for i in range(60,len(train_data)):
    x_train_data=list(x_train_data)
    y_train_data=list(y_train_data)
    x_train_data.append(train_data[i-60:i,0])
    y_train_data.append(train_data[i,0])
 
    # 6. Converting the training x and y values to numpy arrays
    x_train_data1, y_train_data1 = np.array(x_train_data), np.array(y_train_data)
 
    # 7. Reshaping training x and y data to make the calculations easier
    x_train_data2 = np.reshape(x_train_data1, (x_train_data1.shape[0],x_train_data1.shape[1],1))

# %% [markdown]
# #### Building the LSTM model

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train_data2.shape[1],1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# %% [markdown]
# #### Compiling and Training the model

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train_data2, y_train_data1, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 57/57 - 11s - loss: 0.0070
# Epoch 2/100
# 57/57 - 4s - loss: 3.1162e-04
# Epoch 3/100
# 57/57 - 3s - loss: 2.9827e-04
# Epoch 4/100
# 57/57 - 4s - loss: 3.0258e-04
# Epoch 5/100
# 57/57 - 4s - loss: 2.9039e-04
# Epoch 6/100
# 57/57 - 4s - loss: 2.6835e-04
# Epoch 7/100
# 57/57 - 3s - loss: 2.6332e-04
# Epoch 8/100
# 57/57 - 3s - loss: 2.5457e-04
# Epoch 9/100
# 57/57 - 4s - loss: 2.5559e-04
# Epoch 10/100
# 57/57 - 4s - loss: 2.3572e-04
# Epoch 11/100
# 57/57 - 4s - loss: 2.4578e-04
# Epoch 12/100
# 57/57 - 4s - loss: 2.2462e-04
# Epoch 13/100
# 57/57 - 4s - loss: 2.1800e-04
# Epoch 14/100
# 57/57 - 4s - loss: 2.1351e-04
# Epoch 15/100
# 57/57 - 4s - loss: 2.0659e-04
# Epoch 16/100
# 57/57 - 4s - loss: 2.0229e-04
# Epoch 17/100
# 57/57 - 3s - loss: 1.9193e-04
# Epoch 18/100
# 57/57 - 3s - loss: 1.9467e-04
# Epoch 19/100
# 57/57 - 4s - loss: 1.9215e-04
# Epoch 20/100
# 57/57 - 4s - loss: 1.7996e-04
# Epoch 21/100
# 57/57 - 4s - loss: 1.7020e-04
# Epoch 22/100
# 57/57 - 4s - loss: 1.7887e-04
# Epoch 23/100
# 57/57 - 4s - loss: 1.5643e-04
# Epoch 24/100
# 57/57 - 4s - loss: 1.5209e-04
# Epoch 25/100
# 57/57 - 3s - loss: 2.1548e-04
# Epoch 26/100
# 57/57 - 3s - loss: 1.9094e-04
# Epoch 27/100
# 57/57 - 3s - loss: 1.6016e-04
# Epoch 28/100
# 57/57 - 4s - loss: 1.3778e-04
# Epoch 29/100
# 57/57 - 4s - loss: 1.5055e-04
# Epoch 30/100
# 57/57 - 3s - loss: 1.5014e-04
# Epoch 31/100
# 57/57 - 3s - loss: 1.3869e-04
# Epoch 32/100
# 57/57 - 3s - loss: 1.2299e-04
# Epoch 33/100
# 57/57 - 4s - loss: 1.2922e-04
# Epoch 34/100
# 57/57 - 3s - loss: 1.2156e-04
# Epoch 35/100
# 57/57 - 3s - loss: 1.3074e-04
# Epoch 36/100
# 57/57 - 3s - loss: 1.0935e-04
# Epoch 37/100
# 57/57 - 3s - loss: 1.0860e-04
# Epoch 38/100
# 57/57 - 4s - loss: 1.0744e-04
# Epoch 39/100
# 57/57 - 3s - loss: 1.1443e-04
# Epoch 40/100
# 57/57 - 3s - loss: 1.0531e-04
# Epoch 41/100
# 57/57 - 3s - loss: 1.2831e-04
# Epoch 42/100
# 57/57 - 3s - loss: 1.2673e-04
# Epoch 43/100
# 57/57 - 4s - loss: 9.7091e-05
# Epoch 44/100
# 57/57 - 3s - loss: 1.2089e-04
# Epoch 45/100
# 57/57 - 3s - loss: 1.1628e-04
# Epoch 46/100
# 57/57 - 4s - loss: 1.0951e-04
# Epoch 47/100
# 57/57 - 4s - loss: 9.1130e-05
# Epoch 48/100
# 57/57 - 3s - loss: 9.6761e-05
# Epoch 49/100
# 57/57 - 3s - loss: 9.1907e-05
# Epoch 50/100
# 57/57 - 3s - loss: 1.0986e-04
# Epoch 51/100
# 57/57 - 3s - loss: 9.4314e-05
# Epoch 52/100
# 57/57 - 4s - loss: 9.9610e-05
# Epoch 53/100
# 57/57 - 3s - loss: 9.4207e-05
# Epoch 54/100
# 57/57 - 3s - loss: 9.3344e-05
# Epoch 55/100
# 57/57 - 3s - loss: 8.5961e-05
# Epoch 56/100
# 57/57 - 3s - loss: 1.0382e-04
# Epoch 57/100
# 57/57 - 4s - loss: 9.4383e-05
# Epoch 58/100
# 57/57 - 3s - loss: 9.5093e-05
# Epoch 59/100
# 57/57 - 3s - loss: 8.2827e-05
# Epoch 60/100
# 57/57 - 3s - loss: 8.3215e-05
# Epoch 61/100
# 57/57 - 4s - loss: 1.1724e-04
# Epoch 62/100
# 57/57 - 3s - loss: 7.9895e-05
# Epoch 63/100
# 57/57 - 3s - loss: 7.6049e-05
# Epoch 64/100
# 57/57 - 3s - loss: 8.5792e-05
# Epoch 65/100
# 57/57 - 3s - loss: 7.3495e-05
# Epoch 66/100
# 57/57 - 4s - loss: 1.0476e-04
# Epoch 67/100
# 57/57 - 3s - loss: 7.6782e-05
# Epoch 68/100
# 57/57 - 3s - loss: 7.7062e-05
# Epoch 69/100
# 57/57 - 4s - loss: 8.2170e-05
# Epoch 70/100
# 57/57 - 3s - loss: 8.4385e-05
# Epoch 71/100
# 57/57 - 4s - loss: 8.5279e-05
# Epoch 72/100
# 57/57 - 4s - loss: 7.0641e-05
# Epoch 73/100
# 57/57 - 3s - loss: 7.1824e-05
# Epoch 74/100
# 57/57 - 3s - loss: 6.7788e-05
# Epoch 75/100
# 57/57 - 4s - loss: 1.0890e-04
# Epoch 76/100
# 57/57 - 3s - loss: 7.8015e-05
# Epoch 77/100
# 57/57 - 3s - loss: 8.0594e-05
# Epoch 78/100
# 57/57 - 3s - loss: 8.7225e-05
# Epoch 79/100
# 57/57 - 3s - loss: 8.6974e-05
# Epoch 80/100
# 57/57 - 4s - loss: 7.1944e-05
# Epoch 81/100
# 57/57 - 3s - loss: 7.4238e-05
# Epoch 82/100
# 57/57 - 3s - loss: 7.1538e-05
# Epoch 83/100
# 57/57 - 3s - loss: 6.4304e-05
# Epoch 84/100
# 57/57 - 8s - loss: 7.2715e-05
# Epoch 85/100
# 57/57 - 6s - loss: 6.6544e-05
# Epoch 86/100
# 57/57 - 5s - loss: 6.9845e-05
# Epoch 87/100
# 57/57 - 6s - loss: 8.1256e-05
# Epoch 88/100
# 57/57 - 5s - loss: 6.9439e-05
# Epoch 89/100
# 57/57 - 5s - loss: 7.1560e-05
# Epoch 90/100
# 57/57 - 5s - loss: 7.5816e-05
# Epoch 91/100
# 57/57 - 5s - loss: 7.2351e-05
# Epoch 92/100
# 57/57 - 5s - loss: 6.5851e-05
# Epoch 93/100
# 57/57 - 5s - loss: 8.1110e-05
# Epoch 94/100
# 57/57 - 5s - loss: 9.3291e-05
# Epoch 95/100
# 57/57 - 5s - loss: 7.2081e-05
# Epoch 96/100
# 57/57 - 6s - loss: 7.6709e-05
# Epoch 97/100
# 57/57 - 5s - loss: 6.6932e-05
# Epoch 98/100
# 57/57 - 5s - loss: 7.5276e-05
# Epoch 99/100
# 57/57 - 5s - loss: 6.6965e-05
# Epoch 100/100
# 57/57 - 5s - loss: 6.8027e-05

# %% [markdown]
# #### Testing the model

# %%
# 1. Creating a dataset for testing
test_data = scaled_data[training_data_len - 60: , : ]
x_test = []
y_test =  dataset[training_data_len : , : ]
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])
 
# 2.  Convert the values into arrays for easier computation
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
 
# 3. Making predictions on the testing data
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
 
valid['Predictions'] = predictions
 
fig = plt.figure(figsize=(15, 10)) 
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close')
 
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
 
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
 
plt.show()

# %%
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
print(rmse)
# Out:
# 3.3066628534066207

# %%
valid[['Close', 'Predictions']].head(10)
# Out:
#                  Close  Predictions
# Date
# 2019-05-20  129.990005   133.221130
# 2019-05-21  129.050003   132.693054
# 2019-05-22  130.070007   131.759705
# 2019-05-23  129.970001   132.866318
# 2019-05-24  129.500000   132.734116
# 2019-05-28  127.629997   132.253860
# 2019-05-29  128.169998   130.320053
# 2019-05-30  128.610001   130.948685
# 2019-05-31  128.000000   131.370667
# 2019-06-03  128.979996   130.708435

# %%
model.save('Stock_pred_model.h5')

# %% [markdown]
# #### predicting future dates
